# %% [markdown]
# # Jupyter Notebook
# 주피터 노트북은 웹 브라우저 상에서 개발을 할 수 있는 도구이며, 코드를 Cell 단위로 묶어서 실행하고 그래프나 표, 그리고 이미지나 영상 등을 쉽게 볼 수 있어서 특히 데이터 관련 직업을 할 때 많이 활용됩니다.
#
# > 교육을 위한 강의 노트로도 아주 훌륭해요!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![anaconda.png](attachment:anaconda.png)

# %% [markdown]
# ## 특징
#
# 1. 코드를 Cell 단위로 작성 및 실행
# 1. 마크다운을 통한 문서화
# 1. 그래프나 표 등을 실시간으로 확인
# 1. html, pdf 등 파일로 저장

# %% [markdown]
# ## 사전 학습 자료
#
# 다음 링크에서 파이썬 기본편에 대한 학습을 하실 수 있습니다.
# [나도코딩 블로그](https://nadocoding.tistory.com)

# %%
# %%HTML
# <iframe width="640" height="360" src="https://www.youtube.com/embed/kWiCuklohdY" title="파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 [나도코딩]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="640" height="360" src="https://www.youtube.com/embed/kWiCuklohdY" title="파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 [나도코딩]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 파이썬 기본문법

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("환영합니다")
# Out:
# 환영합니다

# %%
name = "hyoin"
print(name)
# Out:
# hyoin

# %%
print("Ctrl + Enter : 현재 Cell 실행")
# Out:
# Ctrl + Enter : 현재 Cell 실행

# %%
print("Shift + Enter : 현재 Cell 실행 후 다음 Cell 선택")
# Out:
# Shift + Enter : 현재 Cell 실행 후 다음 Cell 선택

# %%
print("Alt + Enter : 현재 Cell 실행 후 다음 위치에 Cell 삽입")
# Out:
# Alt + Enter : 현재 Cell 실행 후 다음 위치에 Cell 삽입

# %%
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## 모듈 사용

# %%
import random
# Teb을 누르면 자동완성
print(random.randint(1, 35))
# Out:
# 15

# %%
# 무엇인지 궁금할때
# random.randint?
# Sorce Code 내용까지 확인
# random.randint??

# %%
num = 3

# %%
num *= 2

# %%
num += 4

# %%
print(num)
# Out:
# 10

# %%
# import time
# for i in range(100):
#     print(i)
#     time.sleep(1)
#     # interrupt (ii 클릭)

# %% [markdown]
# ---
# ## 시각화 예제 1 : 그래프
# - matplotlib를 이용하면 다양한 그래프를 그릴 수 있으며 수행결과를 바로 확인할 수 있습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ## 시각화 예제 2 : 테이블
#
# - pandas는 복잡한 데이터를 분석할 때 아주 유용합니다

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_9cf0c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_9cf0c_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_9cf0c_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_9cf0c_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_9cf0c_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_9cf0c_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_9cf0c_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_9cf0c_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_9cf0c_level1_col4" class="col_heading level1 col4" >Tumour</th>
# ...
